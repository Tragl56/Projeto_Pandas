# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados_new = pd.read_csv(url, sep=';')
dados_new
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados_new.head(6)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN
# 5  1200.0         NaN     NaN

# %%
dados_new.tail(6)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32954   755  14000.0         NaN     NaN
# 32955    27    800.0       350.0    25.0
# 32956    78   1800.0       800.0    40.0
# 32957    48   1400.0       509.0    37.0
# 32958    70   3000.0       760.0     NaN
# 32959   250   6500.0      4206.0  1109.0

# %%
type(dados_new)
# Out:
# pandas.core.frame.DataFrame

# %%
dados_new.to_csv('primeiro.csv')

# %% [markdown]
# ## Características gerais da base de dados

# %%
dados_new.shape
# Out:
# (32960, 9)

# %%
dados_new.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados_new['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados_new[['Quartos','Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## Qual o valor médio de aluguel por tipo de imóvel?

# %%
dados_new.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados_new['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %%
dados_new.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados_new.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados_new.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                      Valor
# Tipo
# Prédio Inteiro               498637.239203
# Indústria                    120000.000000
# Galpão/Depósito/Armazém       53407.062600
# Terreno Padrão                32567.714286
# Hotel                         25000.000000
# Loteamento/Condomínio         22000.000000
# Conjunto Comercial/Sala       14715.045521
# Casa Comercial                14478.264151
# Loja/Salão                    13769.646770
# Sítio                         12499.000000
# Casa de Condomínio            11952.061245
# Loja Shopping/ Ct Comercial    8126.178862
# Casa                           6793.454922
# Chácara                        4900.000000
# Apartamento                    4744.614648
# Flat                           4546.189076
# Loft                           2557.882353
# Studio                         2400.000000
# Box/Garagem                    1899.756098
# Casa de Vila                   1574.369478
# Pousada/Chalé                  1480.000000
# ...

# %%
df_preco_tipo = dados_new.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=False)
df_preco_tipo.plot(kind='barh', figsize=(10,6), color = 'Red')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## Removendo os imóveis comerciais

# %%
dados_new.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados_new.query('Tipo in @imoveis_comerciais')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
dados_new.query('Tipo not in @imoveis_comerciais')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df = dados_new.query('Tipo not in @imoveis_comerciais')
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=True)
df_preco_tipo.plot(kind='barh', figsize=(10,6), color = 'Red')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## Qual o percentual de cada tipo de imóvel na nossa base de dados?

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo', ascending=False)
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Quitinete             0.036173
# Loft                  0.002207
# Flat                  0.020596
# Casa de Vila          0.010774
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Apartamento           0.845139

# %%
df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')

df_percentual_tipo.plot(kind='bar', figsize=(12,8), color = 'Blue',
                         xlabel='Tipos' , ylabel= 'Percentual' );

# %% [markdown]
# ### **Selecionando apenas os imóveis do tipo apartamento**

# %%
df.query('Tipo == "Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df_apartamento = df.query('Tipo == "Apartamento"')
df_apartamento.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# # Tratando e filtrando os dados

# %% [markdown]
# ## Lidando com dados nulos

# %%
df.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32953  False   False    False  False   False  False  False       False  False
# 32955  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [23111 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            9
# Condominio    1865
# IPTU          6879
# dtype: int64

# %%
df.fillna(0)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# ## Removendo registros

# %%
df.query('Valor == 0 | Condominio == 0' )
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 5             Apartamento              Vista Alegre        3      1       0
# 7      Casa de Condomínio           Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                     Ramos        2      2       0
# 10            Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 32859                Casa              Campo Grande        1      0       0
# 32865        Casa de Vila                    Pavuna        2      0       0
# 32893                Casa  Recreio dos Bandeirantes        4      2       2
# 32911                Casa             Bento Ribeiro        2      1       0
# 32931                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# ...

# %%
df.query('Valor == 0 | Condominio == 0' ).index
# Out:
# Index([    1,     5,     7,     8,    10,    18,    31,    76,   113,   117,
#        ...
#        32732, 32739, 32778, 32804, 32809, 32859, 32865, 32893, 32911, 32931],
#       dtype='int64', length=1872)

# %%
remover = df.query('Valor == 0 | Condominio == 0' ).index

# %%
df = df[(df['Valor'] != 0) & (df['Condominio'] != 0)]

# %%
df.query('Valor == 0 | Condominio == 0' )
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0     Quitinete    Copacabana        1      0       0    40  1700.0
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 11  Apartamento        Grajaú        2      1       0    70  1500.0
#
#     Condominio  IPTU
# 0        500.0  60.0
# 3        390.0  20.0
# 4        230.0   0.0
# 6        301.0  17.0
# 11       642.0  74.0

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Apartamento', 'Flat', 'Casa de Condomínio', 'Casa',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df.drop('Tipo', axis=1 , inplace=True)

# %%
df.head()
# Out:
#           Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# 0     Copacabana        1      0       0    40  1700.0       500.0  60.0
# 3         Centro        1      0       0    15   800.0       390.0  20.0
# 4   Higienópolis        1      0       0    48   800.0       230.0   0.0
# 6       Cachambi        2      0       0    50  1300.0       301.0  17.0
# 11        Grajaú        2      1       0    70  1500.0       642.0  74.0

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### **1. Apartamentos que possuem `1 quarto` e `aluguel menor que 1200`**

# %%
df['Quartos'] == 1
# Out:
# 0         True
# 3         True
# 4         True
# 6        False
# 11       False
#          ...
# 32953    False
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# Name: Quartos, Length: 21239, dtype: bool

# %%
selecao1 = df['Quartos'] == 1
df[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0           Copacabana        1      0       0    40  1700.0       500.0
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 14          Copacabana        1      0       0    27  1800.0       501.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32945       Copacabana        1      0       0    22  1500.0       286.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 0       60.0
# 3       20.0
# 4        0.0
# 13      50.0
# 14       0.0
# ...

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
# 32955                   Centro        0      0       0    27   800.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32763        Glória        1      0       0    10   400.0       107.0   10.0
# 32818      Flamengo        1      0       0    23   900.0       605.0    0.0
# 32844        Centro        1      0       0    24  1100.0       323.0    0.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [823 rows x 8 columns]

# %%
df_1 = df[selecao_final]

# %% [markdown]
# ### **2. `Apartamentos` que possuem pelo menos `2 quartos`, `aluguel menor que 3000` e `area maior que 70`**

# %%
selecao = (df['Quartos'] >= 2) & (df['Valor'] < 3000) & (df['Area'] > 70)
df[selecao]
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    0.0
# ...

# %%
df2 = df[selecao]

# %% [markdown]
# ## Salvando os dados

# %%
df.to_csv('dados_apartatados.csv')

# %%
pd.read_csv('dados_apartatados.csv')
# Out:
#        Unnamed: 0                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0               0            Copacabana        1      0       0    40  1700.0
# 1               3                Centro        1      0       0    15   800.0
# 2               4          Higienópolis        1      0       0    48   800.0
# 3               6              Cachambi        2      0       0    50  1300.0
# 4              11                Grajaú        2      1       0    70  1500.0
# ...           ...                   ...      ...    ...     ...   ...     ...
# 21234       32953                 Méier        2      0       0    70   900.0
# 21235       32955                Centro        0      0       0    27   800.0
# 21236       32956           Jacarepaguá        3      1       2    78  1800.0
# 21237       32957  São Francisco Xavier        2      1       0    48  1400.0
# 21238       32958                Leblon        2      0       0    70  3000.0
#
#        Condominio  IPTU
# ...

# %%
df.to_csv('dados_apartatados.csv', index = False)

# %%
pd.read_csv('dados_apartatados.csv')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                Copacabana        1      0       0    40  1700.0       500.0
# 1                    Centro        1      0       0    15   800.0       390.0
# 2              Higienópolis        1      0       0    48   800.0       230.0
# 3                  Cachambi        2      0       0    50  1300.0       301.0
# 4                    Grajaú        2      1       0    70  1500.0       642.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 21234                 Méier        2      0       0    70   900.0       490.0
# 21235                Centro        0      0       0    27   800.0       350.0
# 21236           Jacarepaguá        3      1       2    78  1800.0       800.0
# 21237  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 21238                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      60.0
# ...

# %%
df.to_csv('dados_apartatados.csv', index = False, sep=';')

# %%
pd.read_csv('dados_apartatados.csv')
# Out:
#       Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0                  Copacabana;1;0;0;40;1700.0;500.0;60.0
# 1                       Centro;1;0;0;15;800.0;390.0;20.0
# 2                  Higienópolis;1;0;0;48;800.0;230.0;0.0
# 3                    Cachambi;2;0;0;50;1300.0;301.0;17.0
# 4                      Grajaú;2;1;0;70;1500.0;642.0;74.0
# ...                                                  ...
# 21234                    Méier;2;0;0;70;900.0;490.0;48.0
# 21235                   Centro;0;0;0;27;800.0;350.0;25.0
# 21236             Jacarepaguá;3;1;2;78;1800.0;800.0;40.0
# 21237    São Francisco Xavier;2;1;0;48;1400.0;509.0;37.0
# 21238                   Leblon;2;0;0;70;3000.0;760.0;0.0
#
# [21239 rows x 1 columns]

# %%
pd.read_csv('dados_apartatados.csv', sep=';' )
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                Copacabana        1      0       0    40  1700.0       500.0
# 1                    Centro        1      0       0    15   800.0       390.0
# 2              Higienópolis        1      0       0    48   800.0       230.0
# 3                  Cachambi        2      0       0    50  1300.0       301.0
# 4                    Grajaú        2      1       0    70  1500.0       642.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 21234                 Méier        2      0       0    70   900.0       490.0
# 21235                Centro        0      0       0    27   800.0       350.0
# 21236           Jacarepaguá        3      1       2    78  1800.0       800.0
# 21237  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 21238                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      60.0
# ...

# %%
df_1.to_csv('filtro_1.csv', index=False, sep=";")
df2.to_csv('filtro_2.csv', index=False, sep=";")

# %% [markdown]
# # Manipulando os dados

# %% [markdown]
# ## Criando colunas numéricas

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')
dados = dados.fillna(0)
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         0.0     0.0
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     0.0

# %%
dados['Valor_por_mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         0.0     0.0         7000.0
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     0.0         1030.0

# %%
dados['valor_por_mes'] = dados['Valor_por_mes'] * dados['IPTU']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  valor_por_mes
# 0  1700.0       500.0    60.0         2200.0       132000.0
# 1  7000.0         0.0     0.0         7000.0            0.0
# 2  5200.0      4020.0  1111.0         9220.0     10243420.0
# 3   800.0       390.0    20.0         1190.0        23800.0
# 4   800.0       230.0     0.0         1030.0            0.0

# %% [markdown]
# ## Criando colunas categóricas

# %%
dados['Discricao'] = dados['Tipo'] + ' em ' + dados['Bairro']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  valor_por_mes  \
# 0  1700.0       500.0    60.0         2200.0       132000.0
# 1  7000.0         0.0     0.0         7000.0            0.0
# 2  5200.0      4020.0  1111.0         9220.0     10243420.0
# 3   800.0       390.0    20.0         1190.0        23800.0
# 4   800.0       230.0     0.0         1030.0            0.0
#
#                                     Discricao
# 0                     Quitinete em Copacabana
# 1                     Casa em Jardim Botânico
# ...

# %%
dados['Discricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] \
                      + ' com ' + dados['Quartos'].astype(str) + ' quartos' \
                      + ' e ' + dados['Vagas'].astype(str) + ' vagas'
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  valor_por_mes  \
# 0  1700.0       500.0    60.0         2200.0       132000.0
# 1  7000.0         0.0     0.0         7000.0            0.0
# 2  5200.0      4020.0  1111.0         9220.0     10243420.0
# 3   800.0       390.0    20.0         1190.0        23800.0
# 4   800.0       230.0     0.0         1030.0            0.0
#
#                                            Discricao
# 0    Quitinete em Copacabana com 1 quartos e 0 vagas
# ...

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: 'Sim' if x > 0 else 'Não')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  valor_por_mes  \
# 0  1700.0       500.0    60.0         2200.0       132000.0
# 1  7000.0         0.0     0.0         7000.0            0.0
# 2  5200.0      4020.0  1111.0         9220.0     10243420.0
# 3   800.0       390.0    20.0         1190.0        23800.0
# 4   800.0       230.0     0.0         1030.0            0.0
#
#                                            Discricao Possui_suite
# 0    Quitinete em Copacabana com 1 quartos e 0 vagas          Não
# ...

# %%
dados.to_csv('dados_completos_dev_new.csv')
